# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
	'国家': ['中国', '美国', '日本'],
	'地区': ['亚洲', '北美', '亚洲'],
	'人口': [13.97, 3.28, 1.26],
	'GDP': [14.34, 21.43, 5.08]	
})
df2 = pd.DataFrame({
	'A': 1.,
	'B': pd.Timestamp('20130102'),
	'C': pd.Series([1,3,5,6], index=list(range(4)), dtype='float32'), ## 只有一个索引
	'D': np.array([3] * 4, dtype='int32'),
	'E': pd.Categorical(['test', 'train', 'test', 'train']),
	'F': 'foo'
})
df3 = pd.read_excel('12.xlsx')
df3
# Out:
#       证券代码 证券名称       交易时间       开盘价        最高价       最低价        收盘价  \
# 0       12  南玻A 1992-02-28  0.335729   0.451136  0.335729   0.440644
# 1       12  南玻A 1992-03-02  0.440644   0.467922  0.411268   0.411268
# 2       12  南玻A 1992-03-03  0.415465   0.419661  0.386088   0.390285
# 3       12  南玻A 1992-03-04  0.386088   0.398678  0.379793   0.381892
# 4       12  南玻A 1992-03-05  0.386088   0.386088  0.377695   0.383990
# ...    ...  ...        ...       ...        ...       ...        ...
# 7003    12  南玻A 2021-05-21  8.700000   8.720000  8.330000   8.540000
# 7004    12  南玻A 2021-05-24  8.500000   9.070000  8.390000   8.830000
# 7005    12  南玻A 2021-05-25  8.950000   9.140000  8.780000   9.060000
# 7006    12  南玻A 2021-05-26  9.080000   9.800000  9.060000   9.690000
# 7007    12  南玻A 2021-05-27  9.790000  10.220000  9.540000  10.090000
#
#             涨跌      涨跌幅%       成交量        成交额
# 0           ——        ——     23200     114000
# 1    -0.029376 -6.666665    295000    2891000
# 2    -0.020983 -5.102037    173500    1613550
# 3    -0.008393 -2.150539    197000    1792700
# 4     0.002098  0.549447    204500    1871175
# ...        ...       ...       ...        ...
# 7003     -0.38 -4.260091  77711419  662455344
# 7004      0.29  3.395784  62523141  552836880
# 7005      0.23  2.604762  44806396  402174496
# 7006  0.629999  6.953633  61581870  593758112
# 7007  0.400001  4.127973  51177404  514052448
#
# [7008 rows x 11 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7008 entries, 0 to 7007
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   证券代码    7008 non-null   int64
#  1   证券名称    7008 non-null   object
#  2   交易时间    7008 non-null   datetime64[ns]
#  3   开盘价     7008 non-null   float64
#  4   最高价     7008 non-null   float64
#  5   最低价     7008 non-null   float64
#  6   收盘价     7008 non-null   float64
#  7   涨跌      7008 non-null   object
#  8   涨跌幅%    7008 non-null   object
#  9   成交量     7008 non-null   int64
#  10  成交额     7008 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(3)
# memory usage: 602.4+ KB

# %%
df3.T.loc['开盘价', '1992-02-28':'2021-05-27'].plot()
# Out:
# <AxesSubplot:>
